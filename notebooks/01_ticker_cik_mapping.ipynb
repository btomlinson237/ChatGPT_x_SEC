# %%
from sec_cik_mapper import StockMapper

# %%
stock_mapper = StockMapper()

# %%
cik_to_tickers = stock_mapper.cik_to_tickers
print(cik_to_tickers)
# Out:
# {'0000001750': {'AIR'}, '0000001800': {'ABT'}, '0000001961': {'WDDD'}, '0000002098': {'ACU'}, '0000002178': {'AE'}, '0000002186': {'BKTI'}, '0000002230': {'ADX'}, '0000002488': {'AMD'}, '0000002809': {'AEM'}, '0000002969': {'APD'}, '0000003197': {'CECO'}, '0000003453': {'MATX'}, '0000003499': {'ALX'}, '0000003545': {'ALCO'}, '0000003570': {'LNG'}, '0000004127': {'SWKS'}, '0000004281': {'HWM', 'HWM-P'}, '0000004447': {'HES'}, '0000004457': {'UHAL-B', 'UHAL'}, '0000004904': {'AEP'}, '0000004962': {'AXP'}, '0000004977': {'AFL'}, '0000005094': {'VBF'}, '0000005272': {'AIG', 'AIG-PA'}, '0000005513': {'UNM', 'UNMA'}, '0000005981': {'AVD'}, '0000006176': {'AP', 'AP-WT'}, '0000006201': {'AAL'}, '0000006207': {'AXR'}, '0000006281': {'ADI'}, '0000006494': {'ANDR'}, '0000006845': {'APOG'}, '0000006951': {'AMAT'}, '0000006955': {'EPAC'}, '0000007084': {'ADM'}, '0000007323': {'EAI'}, '0000007332': {'SWN'}, '0000007431': {'AWI'}, '0000007536': {'ARW'}, '0000007623': {'ARTW'}, '0000007789': {'ASBA'
# ...

# %%
ticker_to_cik = stock_mapper.ticker_to_cik
print(ticker_to_cik)
# Out:
# {'AIR': '0000001750', 'ABT': '0000001800', 'WDDD': '0000001961', 'ACU': '0000002098', 'AE': '0000002178', 'BKTI': '0000002186', 'ADX': '0000002230', 'AMD': '0000002488', 'AEM': '0000002809', 'APD': '0000002969', 'CECO': '0000003197', 'MATX': '0000003453', 'ALX': '0000003499', 'ALCO': '0000003545', 'LNG': '0000003570', 'SWKS': '0000004127', 'HWM': '0000004281', 'HWM-P': '0000004281', 'HES': '0000004447', 'UHAL': '0000004457', 'UHAL-B': '0000004457', 'AEP': '0000004904', 'AXP': '0000004962', 'AFL': '0000004977', 'VBF': '0000005094', 'AIG': '0000005272', 'AIG-PA': '0000005272', 'UNM': '0000005513', 'UNMA': '0000005513', 'AVD': '0000005981', 'AP': '0000006176', 'AP-WT': '0000006176', 'AAL': '0000006201', 'AXR': '0000006207', 'ADI': '0000006281', 'ANDR': '0000006494', 'APOG': '0000006845', 'AMAT': '0000006951', 'EPAC': '0000006955', 'ADM': '0000007084', 'EAI': '0000007323', 'SWN': '0000007332', 'AWI': '0000007431', 'ARW': '0000007536', 'ARTW': '0000007623', 'ASB': '0000007789', 'ASB-PE': 
# ...

# %%
df = stock_mapper.raw_dataframe
print(df)
# Out:
#               CIK Ticker                                               Name  \
# 0      0000001750    AIR                                           Aar Corp
# 1      0000001800    ABT                                Abbott Laboratories
# 2      0000001961   WDDD                                         Worlds Inc
# 3      0000002098    ACU                                   Acme United Corp
# 4      0000002178     AE                     Adams Resources & Energy, Inc.
# ...           ...    ...                                                ...
# 10895  0001990446   GRPS                    Trans American Aquaculture, Inc
# 10896  0001990472   TYGJ  American Tuoyuan International Securities Grou...
# 10897  0001991946   CGBS                             Crown Lng Holdings Ltd
# 10898  0001993004    NWE                    Northwestern Energy Group, Inc.
# 10899  0001994347   MDLX                      Modulex Modular Buildings Plc
#
#       Exchange
# 0         NYSE
# 1         NYSE
# ...

# %%
from pathlib import Path

# %%
csv_path = Path("../data/tickers/full_ticker_mapping.csv")

# %%
stock_mapper.save_metadata_to_csv(csv_path)
